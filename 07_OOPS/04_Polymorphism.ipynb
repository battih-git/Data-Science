# %% [markdown]
# # Polymorphism
# Polymorphism in Python is a core concept in object-oriented programming (OOP) that allows objects of different classes to be treated as if they were of the same class, through a common interface. The word polymorphism means "many forms".
# It provides a way to perform single action in different forms

# %% [markdown]
# # Method Overriding
# This method allows a child class to provide a specific implementation of a method that is already defined in its parent class

# %%
# Base class
from abc import ABC
class Animal:
    def speak(self):
        print(f"Say Something")
    
class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

dog = Dog()
cat = Cat()
print(dog.speak())
print(cat.speak())
# Out:
# Woof!
# Meow!

# %% [markdown]
# # Duck Typing (Dynamic Typing)
#
# Python uses duck typing, which means an object’s suitability is determined by the presence of certain methods and properties, rather than the actual type of the object.

# %% [markdown]
# The type or class of an object is less important than the methods and attributes it supports. It follows the principle: "If it looks like a duck, swims like a duck, and quacks like a duck, then it probably is a duck."

# %%
class Dog:
    def speak(self):
        print("Woof!")

class Cat:
    def speak(self):
        print('Meow!')

def animal_speak(animal):
    animal.speak()

dog = Dog()
cat = Cat()
animal_speak(dog)
animal_speak(cat)
# Out:
# Woof!
# Meow!

# %% [markdown]
# Polymorphism using abstract classes and interfaces in Python. Python uses the abc module (Abstract Base Classes) to create abstract classes and enforce method implementation in subclasses

# %%
from abc import ABC, abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Rectangle(Shape):
    def __init__(self, length, width):
        super().__init__()
        self.length = length
        self.width = width
    def area(self):
        return self.length * self.width
    
class Circle(Shape):
    def __init__(self, radius):
        super().__init__()
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius
    
rectangle = Rectangle(10,10)
circle = Circle(5)
print(rectangle.area())
print(circle.area())
# Out:
# 100
# 78.5
